# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# %%
# Load your trained model
model = load_model('D:\\SKAY\\Projects\\KEEP\\VScode\\Ocular Recognition Disease\\my_occular_trained_model.h5')  

# Function to preprocess images for prediction
def preprocess_image(img):
    img = cv2.resize(img, (150, 150))
    img = img / 255.0  # Normalize pixel values to [0, 1]
    return img

# Function to make predictions and update the GUI
def predict_image():
    file_path = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
    if file_path:
        img = cv2.imread(file_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_processed = preprocess_image(img_rgb)
        img_processed = np.expand_dims(img_processed, axis=0)
        prediction = model.predict(img_processed)
       # predicted_class = "Pneumonia" if prediction > 0.5 else "Normal"

    

        # Get the class with the highest probability
        predicted_class = np.argmax(predictions)


        # Update the GUI with the result
        result_label.config(text=f"Prediction: {predicted_class}")

        # Display the selected image in the GUI
        img = Image.fromarray(img_rgb)
        img.thumbnail((300, 300))
        img = ImageTk.PhotoImage(img)
        image_label.config(image=img)
        image_label.image = img

# Create the main window
root = tk.Tk()
root.title("Occular Disease Classification App")

# Create and configure widgets
select_button = tk.Button(root, text="Select Image", command=predict_image)
result_label = tk.Label(root, text="Prediction: ")
image_label = tk.Label(root)

# Pack widgets
select_button.pack(pady=10)
result_label.pack(pady=10)
image_label.pack()

# Start the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Users\asame\AppData\Local\Temp\ipykernel_12776\2742100165.py", line 18, in predict_image
#     prediction = model.predict(img_processed)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1727, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\framework\func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\eager\def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\framework\func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\training.py:1569 predict_function  *
#         return step_function(self, iterator)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\training.py:1559 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\training.py:1552 run_step  **
#         outputs = model.predict_step(data)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\training.py:1525 predict_step
#         return self(x, training=False)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     d:\SKAY\Programs\Anaconda\envs\suii\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:270 assert_input_compatibility
#         ', found shape=' + display_shape(x.shape))
#
#     ValueError: Input 0 is incompatible with layer sequential: expected shape=(None, 224, 224, 3), found shape=(None, 150, 150, 3)
